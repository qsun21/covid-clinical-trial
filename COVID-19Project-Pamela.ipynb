# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Load the CSV (load date data as proper date types)
covid = "~/desktop/clinical-trial_data.csv"

# Use Pandas to read data
covid_df = pd.read_csv(covid)
covid_df.head()
# Out:
#    Rank   NCT Number                                              Title  \
# 0     1  NCT04425538  A Phase 2 Trial of Infliximab in Coronavirus D...
# 1     2  NCT04452435  Safety and Efficacy of C21 in Subjects With CO...
# 2     3  NCT04445272  Clinical Trial to Evaluate the Effectiveness a...
# 3     4  NCT04355741  Gut Microbiota, "Spark and Flame" of COVID-19 ...
# 4     5  NCT04578158  Trial to Study the Adjuvant Benefits of Querce...
#
#   Acronym     Status         Study Results Conditions  \
# 0     NaN  Completed  No Results Available   COVID-19
# 1     NaN  Completed           Has Results   COVID-19
# 2     NaN  Completed  No Results Available   COVID-19
# 3     NaN  Completed  No Results Available   COVID-19
# 4     NaN  Completed  No Results Available   COVID-19
#
#                                        Interventions  \
# 0                                   Drug: Infliximab
# 1                            Drug: C21|Drug: Placebo
# 2                                  Drug: Tocilizumab
# 3                                    Other: Exposure
# 4  Drug: Standard COVID-19 care|Dietary Supplemen...
#
#                                     Outcome Measures  \
# 0  Time to improvement in oxygenation|28-day mort...
# 1  Change From Baseline in C-reactive Protein (CR...
# 2  To calulate the time of intubation|To calculat...
# 3  Differences in gut microbiota composition betw...
# 4  Percentage of subjects with COVID-19 disease p...
#
#                                Sponsor/Collaborators  ... Completion Date  \
# 0  Tufts Medical Center|National Institutes of He...  ...       22-Jan-21
# 1                      Vicore Pharma AB|Orphan Reach  ...       13-Oct-20
# 2  Fundacion SEIMC-GESIDA|Roche Pharma AG|Dynamic...  ...       23-Dec-20
# 3  Universidade Nova de Lisboa|NOVA Medical Schoo...  ...       16-Jul-20
# 4    Liaquat University of Medical & Health Sciences  ...       15-Apr-21
#
#   Start Date Trial Duration  Primary Completion Date First Posted  \
# 0   1-Jun-20            235                22-Jan-21    11-Jun-20
# 1  21-Jul-20             84                13-Oct-20    30-Jun-20
# 2  22-May-20            215                23-Dec-20    24-Jun-20
# 3  20-Apr-20             87                 1-Jul-20    21-Apr-20
# 4  29-Sep-20            198                28-Mar-21     8-Oct-20
#
#   Results First Posted Last Update Posted  \
# 0                  NaN          18-Feb-21
# 1            30-Apr-21          30-Apr-21
# 2                  NaN           3-Feb-21
# 3                  NaN          25-Aug-20
# 4                  NaN          22-Apr-21
#
#                                            Locations  \
# 0  Tufts Medical Center, Boston, Massachusetts, U...
# 1  Department of Medicine, Civil Hospital and B J...
# 2  Hospital Universitario de CabueÃ±es, GijÃ³n, A...
# 3  Hospital CUF Infante Santo, S.A., Lisbon, Port...
# 4  Liaquat University Hospital, JÄmshoro, Sindh,...
#
#                                      Study Documents  \
# 0                                                NaN
# 1  "Study Protocol and Statistical Analysis Plan"...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            URL
# 0  https://ClinicalTrials.gov/show/NCT04425538
# 1  https://ClinicalTrials.gov/show/NCT04452435
# 2  https://ClinicalTrials.gov/show/NCT04445272
# 3  https://ClinicalTrials.gov/show/NCT04355741
# 4  https://ClinicalTrials.gov/show/NCT04578158
#
# [5 rows x 28 columns]

# %%
# The average number of days:
average_days = covid_df ["Trial Duration"].mean()
average_days
# Out:
# 136.09439002671417

# %%
# The total combined number of days:
total_days = covid_df[('Trial Duration')].sum()
total_days
# Out:
# 152834

# %%
# Converting the trial days into weeks and then adding a column to the DataFrame
weeks = covid_df["Trial Duration"]/7
covid_df["Trial Duration (Weeks)"] = weeks

covid_df.head()
# Out:
#    Rank   NCT Number                                              Title  \
# 0     1  NCT04425538  A Phase 2 Trial of Infliximab in Coronavirus D...
# 1     2  NCT04452435  Safety and Efficacy of C21 in Subjects With CO...
# 2     3  NCT04445272  Clinical Trial to Evaluate the Effectiveness a...
# 3     4  NCT04355741  Gut Microbiota, "Spark and Flame" of COVID-19 ...
# 4     5  NCT04578158  Trial to Study the Adjuvant Benefits of Querce...
#
#   Acronym     Status         Study Results Conditions  \
# 0     NaN  Completed  No Results Available   COVID-19
# 1     NaN  Completed           Has Results   COVID-19
# 2     NaN  Completed  No Results Available   COVID-19
# 3     NaN  Completed  No Results Available   COVID-19
# 4     NaN  Completed  No Results Available   COVID-19
#
#                                        Interventions  \
# 0                                   Drug: Infliximab
# 1                            Drug: C21|Drug: Placebo
# 2                                  Drug: Tocilizumab
# 3                                    Other: Exposure
# 4  Drug: Standard COVID-19 care|Dietary Supplemen...
#
#                                     Outcome Measures  \
# 0  Time to improvement in oxygenation|28-day mort...
# 1  Change From Baseline in C-reactive Protein (CR...
# 2  To calulate the time of intubation|To calculat...
# 3  Differences in gut microbiota composition betw...
# 4  Percentage of subjects with COVID-19 disease p...
#
#                                Sponsor/Collaborators  ... Start Date  \
# 0  Tufts Medical Center|National Institutes of He...  ...   1-Jun-20
# 1                      Vicore Pharma AB|Orphan Reach  ...  21-Jul-20
# 2  Fundacion SEIMC-GESIDA|Roche Pharma AG|Dynamic...  ...  22-May-20
# 3  Universidade Nova de Lisboa|NOVA Medical Schoo...  ...  20-Apr-20
# 4    Liaquat University of Medical & Health Sciences  ...  29-Sep-20
#
#   Trial Duration Primary Completion Date  First Posted Results First Posted  \
# 0            235               22-Jan-21     11-Jun-20                  NaN
# 1             84               13-Oct-20     30-Jun-20            30-Apr-21
# 2            215               23-Dec-20     24-Jun-20                  NaN
# 3             87                1-Jul-20     21-Apr-20                  NaN
# 4            198               28-Mar-21      8-Oct-20                  NaN
#
#   Last Update Posted                                          Locations  \
# 0          18-Feb-21  Tufts Medical Center, Boston, Massachusetts, U...
# 1          30-Apr-21  Department of Medicine, Civil Hospital and B J...
# 2           3-Feb-21  Hospital Universitario de CabueÃ±es, GijÃ³n, A...
# 3          25-Aug-20  Hospital CUF Infante Santo, S.A., Lisbon, Port...
# 4          22-Apr-21  Liaquat University Hospital, JÄmshoro, Sindh,...
#
#                                      Study Documents  \
# 0                                                NaN
# 1  "Study Protocol and Statistical Analysis Plan"...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            URL Trial Duration (Weeks)
# 0  https://ClinicalTrials.gov/show/NCT04425538              33.571429
# 1  https://ClinicalTrials.gov/show/NCT04452435              12.000000
# 2  https://ClinicalTrials.gov/show/NCT04445272              30.714286
# 3  https://ClinicalTrials.gov/show/NCT04355741              12.428571
# 4  https://ClinicalTrials.gov/show/NCT04578158              28.285714
#
# [5 rows x 29 columns]

# %%
# Remove Columns
remove_columns = covid_df.drop(columns=['Title','Acronym', 'Study Results','Sponsor/Collaborators', 'Funded Bys','Study Designs', 'Other IDs', 'Primary Completion Date', 'Results First Posted', 'Last Update Posted', 'Study Documents', 'URL'])
remove_columns.head()
# Out:
#    Rank   NCT Number     Status Conditions  \
# 0     1  NCT04425538  Completed   COVID-19
# 1     2  NCT04452435  Completed   COVID-19
# 2     3  NCT04445272  Completed   COVID-19
# 3     4  NCT04355741  Completed   COVID-19
# 4     5  NCT04578158  Completed   COVID-19
#
#                                        Interventions  \
# 0                                   Drug: Infliximab
# 1                            Drug: C21|Drug: Placebo
# 2                                  Drug: Tocilizumab
# 3                                    Other: Exposure
# 4  Drug: Standard COVID-19 care|Dietary Supplemen...
#
#                                     Outcome Measures Gender  \
# 0  Time to improvement in oxygenation|28-day mort...    All
# 1  Change From Baseline in C-reactive Protein (CR...    All
# 2  To calulate the time of intubation|To calculat...    All
# 3  Differences in gut microbiota composition betw...    All
# 4  Percentage of subjects with COVID-19 disease p...    All
#
#                                             Age   Phases  Enrollment  \
# 0    18 Years and older Â  (Adult, Older Adult)  Phase 2          17
# 1  18 Years to 70 Years Â  (Adult, Older Adult)  Phase 2         206
# 2    18 Years and older Â  (Adult, Older Adult)  Phase 2         495
# 3    18 Years and older Â  (Adult, Older Adult)      NaN         115
# 4    18 Years and older Â  (Adult, Older Adult)  Phase 3         152
#
#        Study Type Completion Date Start Date  Trial Duration First Posted  \
# 0  Interventional       22-Jan-21   1-Jun-20             235    11-Jun-20
# 1  Interventional       13-Oct-20  21-Jul-20              84    30-Jun-20
# 2  Interventional       23-Dec-20  22-May-20             215    24-Jun-20
# 3   Observational       16-Jul-20  20-Apr-20              87    21-Apr-20
# 4  Interventional       15-Apr-21  29-Sep-20             198     8-Oct-20
#
#                                            Locations  Trial Duration (Weeks)
# 0  Tufts Medical Center, Boston, Massachusetts, U...               33.571429
# 1  Department of Medicine, Civil Hospital and B J...               12.000000
# 2  Hospital Universitario de CabueÃ±es, GijÃ³n, A...               30.714286
# 3  Hospital CUF Infante Santo, S.A., Lisbon, Port...               12.428571
# 4  Liaquat University Hospital, JÄmshoro, Sindh,...               28.285714

# %%
# Reorganizing the columns using double brackets
covid_df = covid_df[["NCT Number","Trial Duration"]]
covid_df.head()
# Out:
#     NCT Number  Trial Duration
# 0  NCT04425538             235
# 1  NCT04452435              84
# 2  NCT04445272             215
# 3  NCT04355741              87
# 4  NCT04578158             198

# %%
covid_df.boxplot()
covid_df.boxplot(column="Trial Duration", widths=0.2) 

# Set Labels
plt.ylabel("Number of Days")
plt.title("Length of Covid-19 Clinical Trials")
# Out:
# Text(0.5, 1.0, 'Length of Covid-19 Clinical Trials')
